# %%
# !pip install jinja2
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50, 101, size=(50, 5))
df = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=range(1,51)
             )
df.index.name = '學號'
df.columns.name = '科目'
df
# Out:
# 科目   國文   英文   數學   地理  歷史
# 學號
# 1    95   69   57   64  91
# 2    96   75   66   84  95
# 3    88   94   56   79  67
# 4    83   97   94  100  78
# 5    73   93   74   79  72
# 6    72   54   81   81  80
# 7    93   66   52   51  76
# 8    99   56   67   54  63
# 9    82   52  100   90  59
# 10  100   53   75   68  92
# 11   95  100   97   77  73
# 12   91   97   80   76  98
# 13   54   65   87   61  58
# 14   50   76   64   96  70
# 15   95   70   90   52  76
# 16   73   80   56   95  98
# 17   62   56   81   75  56
# 18   91   97   74   66  70
# 19   67   99   69   65  96
# 20   86   69   84   59  60
# 21   95   69   70   84  81
# 22   83   70   70   96  79
# 23   66   83   88   62  59
# 24   94   64   98   65  50
# 25   87   71   70   56  67
# 26   65   99   88   80  63
# 27   73   71   54   53  87
# 28   50   64   82   75  68
# 29   94   82   70   53  68
# 30   84   73   50   64  67
# 31   92   51   97   77  84
# 32   77   65   85   99  59
# 33  100   80   79   56  52
# ...

# %%
def less_60(v):
    if v < 60:
        return 'background-color:red'
df.style.applymap(less_60)
# Out:
# /tmp/ipykernel_48856/3081280398.py:4: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df.style.applymap(less_60)
# <style type="text/css">
# ...

# %%
def style_cells(row):
    return ['background-color: red' if val < 61 else '' for val in row]

df.style.apply(style_cells, axis=1)
# Out:
# <style type="text/css">
# ...

# %%
def style_cells(row):
    if len(row[row < 60]) >= 3:
        return ['background-color: red' for _ in row]
    else:
        return ['','','','','']

df.style.apply(style_cells, axis=1)
# Out:
# <style type="text/css">
# #T_9ac19_row33_col0, #T_9ac19_row33_col1, #T_9ac19_row33_col2, #T_9ac19_row33_col3, #T_9ac19_row33_col4, #T_9ac19_row43_col0, #T_9ac19_row43_col1, #T_9ac19_row43_col2, #T_9ac19_row43_col3, #T_9ac19_row43_col4 {
#   background-color: red;
# }
# </style>
# <table id="T_9ac19">
#   <thead>
#     <tr>
#       <th class="index_name level0" >科目</th>
#       <th id="T_9ac19_level0_col0" class="col_heading level0 col0" >國文</th>
#       <th id="T_9ac19_level0_col1" class="col_heading level0 col1" >英文</th>
#       <th id="T_9ac19_level0_col2" class="col_heading level0 col2" >數學</th>
#       <th id="T_9ac19_level0_col3" class="col_heading level0 col3" >地理</th>
#       <th id="T_9ac19_level0_col4" class="col_heading level0 col4" >歷史</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >學號</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
def less_60(s):
    if V <60:
        return 'background-color:red'
df.style.apply(less_60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/IPython/core/formatters.py:406, in BaseFormatter.__call__(self, obj)
#     404     method = get_real_method(obj, self.print_method)
#     405     if method is not None:
# --> 406         return method()
#     407     return None
#     408 else:
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/formats/style.py:405, in Styler._repr_html_(self)
#     400 """
#     401 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     402 default if an object is returned at the end of a cell.
#     403 """
#     404 if get_option("styler.render.repr") == "html":
# --> 405     return self.to_html()
#     406 return None
#
# ...

# %%
def style_cells(row):
    if len (row[row< 60])
    return['backgrund-color;red'for _ in row]

df.style.apply(style_cells,zxis=1)
