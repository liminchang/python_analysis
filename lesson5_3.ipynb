# %%
import numpy as np
students = np.array([
    [67, 94, 65],
    [78, 92, 68],
    [59, 92, 87]
    ])
students
# Out:
# array([[67, 94, 65],
#        [78, 92, 68],
#        [59, 92, 87]])

# %%
import pandas as pd

pd.DataFrame(data=students,
             index=['stu1','stu2','stu3'],
             columns=['國文','英文','數學']
             )
# Out:
#       國文  英文  數學
# stu1  67  94  65
# stu2  78  92  68
# stu3  59  92  87

# %%
import random
with open('names.txt',encoding='uft-8') as file:
    content = file.read()
    names = content.split("\n")
    randam_names = random.sample(names,10)
    print(random_names)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[11], line 2
#       1 import random
# ----> 2 with open('names.txt',encoding='uft-8') as file:
#       3     content = file.read()
#       4     names = content.split("\n")
#
# File /opt/conda/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# LookupError: unknown encoding: uft-8

# %%
import random
def get_names(nums:int=10):
    with open('names.txt',encoding='utf-8') as file:
        content = file.read()
        names = content.split("\n")
        randam_names = random.sample(names,nums)
    

    return randam_names

get_names(5)
# Out:
# ['林詠斌', '黃佩玲', '楊偉翔', '蔡至剛', '林志成']

# %%
student_nums = 50
data = np.random.randint(50,high=101,size=(student_nums,5))
students = pd.DataFrame(data,
             columns=['國文','英文','數學','地理','探討'],
             index=get_names(student_nums))

students
# Out:
#      國文  英文  數學  地理   探討
# 葉祖雄  76  67  68  65   91
# 周琬婷  83  79  85  91   53
# 林建勳  81  61  67  51   54
# 李淑芳  60  61  71  81   61
# 郭坤花  86  51  60  72   66
# 王泓泰  52  73  91  58   79
# 黃善迪  72  87  66  69   63
# 黃淑芬  94  92  50  80   54
# 黃靜怡  66  65  64  67   95
# 賴佳雯  81  87  96  78   51
# 張明惟  54  99  95  72   73
# 陳逸凡  81  62  86  91   94
# 陳怡伶  56  84  90  64   93
# 蔡士賢  50  75  93  57   92
# 鄭奇翰  75  94  58  67   99
# 李立偉  96  73  53  51   75
# 陳樂紫  76  66  56  88   77
# 陳美惠  84  74  68  72   93
# 林志成  77  93  51  53   55
# 吳晴洋  96  60  87  82   52
# 林冠蕙  86  80  79  80   85
# 陳孝邦  97  93  84  81   62
# 鄧亭聿  65  63  66  95   51
# 翁鈺婷  72  86  51  77   74
# 羅佩樺  51  53  73  69   73
# 周家銘  88  97  68  74   73
# 張軒宸  78  83  57  97   95
# 沈心利  51  95  84  64   78
# 吳柏誠  56  75  97  60   65
# 張彥博  82  74  65  73   96
# 謝貞妃  71  70  63  74   85
# 陳得映  75  69  60  95   81
# 張凱妮  86  90  51  50   59
# 金宜芳  92  91  64  63   91
# 楊韋廷  82  96  80  93   78
# 郭淑真  92  87  82  79  100
# 尚偉倫  83  77  87  83   50
# 葉軍仰  75  95  72  87   87
# 陳家年  95  80  78  86   89
# 龐皓芳  75  56  58  90   98
# 郭舜昇  86  94  90  64   74
# 陳姵彬  98  97  51  52   98
# 艾巧夫  52  95  78  69   85
# 李美洋  86  61  52  92   53
# 林益妏  81  58  54  86  100
# 吳明妮  75  88  60  76   94
# 陳信宏  69  52  88  57   58
# 黃彥孝  94  78  92  88   86
# 賴又琦  67  50  92  82   93
# 林義皓  85  96  91  72   84
